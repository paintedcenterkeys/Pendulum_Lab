fakemiddle=(2*math.pi*math.sqrt(.697/9.8))*(1+(1/16)*(angles*math.pi/180)**2+(11/3072)*((angles*math.pi/180)**4)+(173/737280)*((angles*math.pi/180)**6))
fakeupper=(2*math.pi*math.sqrt(.699/9.8))*(1+(1/16)*(angles*math.pi/180)**2+(11/3072)*((angles*math.pi/180)**4)+(173/737280)*((angles*math.pi/180)**6))
plt.errorbar(np.sort(angles),np.sort(fakemiddle),yerr=np.array([fakemiddle-fakelower,fakeupper-fakemiddle]),label='Predicted')

plt.figure(1)
plt.xlabel('Starting Angle (deg)',fontsize=14)
plt.ylabel('Period (sec)',fontsize=14)
plt.legend(loc=2,bbox_to_anchor=(0.03, 0.45, 0.5, 0.5),fontsize=15, markerscale=1.5)
ax = plt.gca()
ax.tick_params(direction='in',length=6)
plt.show()

plt.figure(2)
residuals_wood=periods_wood-(2*math.pi*math.sqrt(.684/9.8))*(1+(1/16)*(angles_wood*math.pi/180)**2+(11/3072)*((angles_wood*math.pi/180)**4)+(173/737280)*((angles_wood*math.pi/180)**6))
plt.scatter(angles_wood,residuals_wood,label='Wooden Ball')

residuals_cork=periods_cork-(2*math.pi*math.sqrt(.684/9.8))*(1+(1/16)*(angles_cork*math.pi/180)**2+(11/3072)*((angles_cork*math.pi/180)**4)+(173/737280)*((angles_cork*math.pi/180)**6))
plt.scatter(angles_cork,residuals_cork,marker='^',label='Cork Ball')

plt.legend(fontsize=13, markerscale=1.3)
ax.tick_params(direction='in',length=6)
plt.xlabel('Starting Angle (deg)',fontsize=12)
plt.ylabel('Difference from Predicted (sec)',fontsize=12)
plt.show()

plt.figure(3)
fake_badmetal=(2*math.pi*math.sqrt(.827/9.8))*(1+(1/16)*(angles_badmetal*math.pi/180)**2+(11/3072)*((angles_badmetal*math.pi/180)**4)+(173/737280)*((angles_badmetal*math.pi/180)**6))
plt.errorbar(angles_badmetal,periods_badmetal,.003,fmt='o',capsize=2.4,linestyle='none',markersize=5,label='Metal Ball',zorder=1)
plt.plot(np.sort(angles_badmetal),np.sort(fake_badmetal),zorder=2,label='Predicted (adjusted)')
plt.xlabel('Starting Angle (deg)',fontsize=12)
plt.ylabel('Period (sec)',fontsize=12)
plt.legend(loc=2,bbox_to_anchor=(0.03, 0.45, 0.5, 0.5),fontsize=13, markerscale=1.3)
plt.show()

plt.figure(4)
plt.scatter(angles_badmetal,periods_badmetal-fake_badmetal)
ax.tick_params(direction='in',length=6)
plt.xlabel('Starting Angle (deg)',fontsize=12)
plt.ylabel('Difference from Predicted (sec)',fontsize=12)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# <img src="data:image/png;base64,..." width="638.888905813665">
# <img src="data:image/png;base64,..." width="638.888905813665">
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))
# %matplotlib notebook
# Out:
# <style>.container { width:85% !important; }</style>

# %%
arr=np.array([])
arr=np.append(arr,[1])
arr=np.append(arr,[2])
np.append(arr,[3])
# Out:
# array([3.])
